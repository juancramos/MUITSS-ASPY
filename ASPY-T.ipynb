# %%
# system import
import sys
import os
import csv
import config

# data processing
import pandas as pd
import numpy
import spacy
from spacy_cld import LanguageDetector
from afinn import Afinn

# set env
af = Afinn()
PROJECT_PATH = config.data_directory
AFINN_PATH = config.afinn_path

# spacy set language
nlp = spacy.load('en')
language_detector = LanguageDetector()
nlp.add_pipe(language_detector)

# %%
# load dataFrame
df = pd.read_csv('{}/{}.csv'.format(PROJECT_PATH, 'songs'))
df.head()
# Out:
#                        id                        name  popularity  \
# 0  57bgtoPSgt236HzfBOd8kj               Thunderstruck          82
# 1  5pKJtX4wBeby9qIfFhyOJj  Don't Go Breaking My Heart          71
# 2  6gZVQvQZOFpzIy3HblJ20F              Man in the Box          72
# 3  6m59VvDUi0UQsB2eZ9wVbH                      Poison          68
# 4  63vL5oxWrlvaJ0ayNaQnbX                    Istanbul          73
#
#    duration_ms  explicit                artist               artist_id  \
# 0       292880     False                 AC/DC  711MCceyCBcFnzjGY4Q7Un
# 1       271133     False            Elton John  3PhoLpVuITZKcymswpck5b
# 2       284426      True       Alice In Chains  64tNsm6TnZe2zpcMVMOoHL
# 3       261853     False        Bell Biv DeVoe  2zFZiWQJFFshzojycnXoTL
# 4       153813     False  They Might Be Giants  6zB02lwP6L6ZH32nggQiJT
#
#                 album                album_id album_release_date  \
# 0     The Razors Edge  4vu7F6h90Br1ZtYYaqfITy         1990-09-24
# 1  To Be Continued...  7iKDBfOFUtg8E8RbuDhiux         1990-11-08
# 2            Facelift  5LbHbwejgZXRZAgzVAjkhj               1990
# 3              Poison  6H5mxGUWguDjtQ4Uzd8veD         1990-01-01
# 4               Flood  7FwAtuhhWivxvK4aPgyyUD         1990-01-02
#
#                          ...                         liveness  valence  \
# 0                        ...                           0.2170    0.257
# 1                        ...                           0.0685    0.779
# 2                        ...                           0.2130    0.644
# 3                        ...                           0.6120    0.803
# 4                        ...                           0.1360    0.892
#
#      tempo                      p_name              p_artist  \
# 0  133.519               thunderstruck                 ac dc
# 1  131.312  don t go breaking my heart            elton john
# 2  106.463              man in the box       alice in chains
# 3  111.848                      poison        bell biv devoe
# 4  114.144                    istanbul  they might be giants
#
#                                     file_name  has_lyrics  \
# 0               ./data/acdc-thunderstruck.txt        True
# 1  ./data/eltonjohn-dontgobreakingmyheart.txt        True
# 2        ./data/aliceinchains-maninthebox.txt        True
# 3              ./data/bellbivdevoe-poison.txt        True
# 4       ./data/theymightbegiants-istanbul.txt        True
#
#                                               lyrics  is_english  \
# 0    Thunder [x10] I was caught In the middle of ...        True
# 1    Don't go breaking my heart I couldn't if I t...        True
# 2    I'm the man in the box [Album version:] Buri...        True
# 3    [Michael Bivins:] Yeah, Spiderman and Freeze...        True
# 4    Istanbul was Constantinople Now it's Istanbu...        True
#
#                                           t_entities
# 0  {(384, 'Beating'): 'GPE', (380, 'Thunderstruck...
# 1                             {(383, 'Baby'): 'ORG'}
# 2  {(380, 'Jesus Christ'): 'PERSON', (383, 'Music...
# 3  {(380, 'Michael Bivins'): 'PERSON', (380, 'Spi...
# 4  {(384, 'Istanbul'): 'GPE', (383, 'Constantinop...
#
# [5 rows x 30 columns]

# %%
def isTextInEnglish(text):
    doc = nlp(text)
    languages = doc._.languages
    try:
        score = doc._.language_scores['en']
        return score > 0.75
    except:
        return False

# %%
# text cleansing 
def clean_text(text):
    return text.replace('"',"'").replace('“','"').replace('”','"').replace('’','"').replace('‘','"')

def add_lyrics(row):
    if row['has_lyrics']:
        return clean_text(read_file(row['file_name']))
    else:
        return ''
    
def get_lyric_name_path(a, t):
    aaz = a.replace(' ', '').lower()
    taz = t.replace(' ', '').lower()
    title = '{}/{}'.format(aaz, taz)
    print(title)
    file_path = '{}/{}.txt'.format(PROJECT_PATH, title.replace('/','-'))
    path = [title, file_path]

    if not os.path.exists(file_path):
        return path + [True]
    else:
        return path + [False]

# %%
# az data
pattern = r'[^a-z0-9A-z]'
df['p_name'] = df['name'].str.replace(pattern, ' ').str.lower()
df['p_artist'] = df['artist'].str.replace(pattern, ' ').str.lower()
df['file_name'] = df.apply(lambda x: get_lyric_name_path(x['p_artist'], x['p_name'])[1], axis=1)
df['has_lyrics'] = 0
# Out:
# acdc/thunderstruck
# eltonjohn/dontgobreakingmyheart
# aliceinchains/maninthebox
# bellbivdevoe/poison
# theymightbegiants/istanbul
# atribecalledquest/canikickit
# extreme/morethanwords
# theromantics/whatilikeaboutyou
# pantera/cowboysfromhell
# mchammer/ucanttouchthis
# theblackcrowes/hardtohandle
# warrant/cherrypie
# digitalunderground/thehumptydance
# wilsonphillips/holdon
# joediffie/johndeeregreen
# thelas/thereshegoes
# scorpions/windofchange
# depechemode/enjoythesilencesinglemix
# beegees/stayinalivefromsaturdaynightfeversoundtrack
# joediffie/pickupman
# ramjam/blackbetty
# therighteousbrothers/unchainedmelody
# sinadoconnor/nothingcompares2u
# templeofthedog/hungerstrike
# keithwhitley/dontcloseyoureyes
# juangabriel/abrzamemuyfuerte
# pantera/cemeterygates
# man/rayandoelsol
# joediffie/propmeupbesidethejukeboxifidie
# llcoolj/mamasaidknockyouout
# megadeth/holywarsthepunishmentdueremastered2004
# joediffie/pickupman
# tonytoniton/feelsgood
# vanillaice/iceicebaby
# poison/unskinnybop
# heart/alliwannadoismakelovetoyou
# envogue/holdon
# hifive/iliketheway
# jonbonjovi/blazeofgloryfromyounggunsiisoundtrack
# acdc/moneytalks
# modernenglish/imeltwithyourerecorded
# judaspriest/painkiller
# rebamcentire/fancy
# caifanes/laclulaqueexplota
# socialdistortion/storyofmylife
# georgestrait/lovewithoutendamen
# pantera/domination
# ralphtresvant/sensitivity
# robbasedjezrock/ittakestwo
# damnyankees/highenough
# ericjohnson/cliffsofdoverinstrumental
# cocteautwins/cherrycolouredfunk
# keithwhitley/whenyousaynothingatall
# shenandoah/themoonovergeorgia
# guy/letschill
# beegees/howdeepisyourlovefromsaturdaynightfeversoundtrack
# queensrche/silentlucidityremastered2003
# megadeth/tornadoofsoulsremastered2004
# warrant/cherrypie
# ccmusicfactory/gonnamakeyousweateverybodydancenow
# theblackcrowes/shetalkstoangels
# johnnygill/mymymy
# cwmccall/convoy
# janesaddiction/beencaughtstealing
# sammydavisjr/somethingsgottagive
# acdc/areyouready
# megadeth/hangar18remastered2004
# templeofthedog/sayhello2heaven
# newkidsontheblock/stepbystep
# roxette/itmusthavebeenlovefromprettywoman
# hifive/shesplayinghardtoget
# pamtillis/maybeitwasmemphis
# theymightbegiants/birdhouseinyoursoul
# depechemode/policyoftruth2006remasteredversion
# ricardomontaner/tanenamorados
# beegees/nightfeverfromsaturdaynightfeversoundtrack
# scorpions/sendmeanangel
# anagabriel/quincomot
# ricardomontaner/mevaaextraarakaunchainmyheart
# beegees/morethanawomanfromsaturdaynightfeversoundtrack
# levert/babyimready
# gruponiche/gotasdelluvia
# firehouse/loveofalifetime
# llcoolj/aroundthewaygirl
# socialdistortion/ballandchain
# mariahcarey/visionoflove
# billystewart/sittingintheparksingleversion
# paulyoung/ohgirl
# firehouse/donttreatmebad
# jerryrivera/quhaydemalo
# luismiguel/tengotodoexceptoati
# publicenemy/fightthepower
# poison/somethingtobelieveinremastered
# socialdistortion/ringoffire
# heroesdelsilencio/malditoduende
# jerryrivera/amorescomoelnuestro
# ccmusicfactory/gonnamakeyousweateverybodydancenow
# wyntonmarsalis/whereorwhen
# toohort/theghetto
# mykoladmytrovychleontovych/carolofthebells
# joediffie/johndeeregreen
# ettajames/somethingsgotaholdonme
# luismiguel/entrgate
# warrant/uncletomscabin
# donnyhathaway/iloveyoumorethanyoulleverknow
# dougstone/whydidntithinkofthat
# therighteousbrothers/youvelostthatlovinfeelin
# sonicyouth/koolthing
# theblackcrowes/twiceashard
# bluestraveler/butanyway
# slayer/seasonsintheabyss
# richiehavens/herecomesthesun
# janesaddiction/stop
# badreligion/21stcenturydigitalboy
# gilbertosantarosa/conciencia
# lostemerarios/tequiero
# keithwhitley/imnostrangertotherain
# saltnpepa/letstalkaboutsex
# madonna/vogue
# josjos/eltriste
# queensrche/jetcitywomanremastered2003
# oletaadams/gethere
# thesundays/hereswherethestoryends
# culture/theinternationalherb
# brandnubian/slowdown
# cocteautwins/heavenorlasvegas
# dougstone/inadifferentlight
# lostemerarios/derrotadoysincario
# rickynelson/lonesometown1990digitalremaster
# anidifranco/bothhands
# alejandraguzman/eternamentebella
# lostemerarios/creoquevoyallorar
# kidfrost/laraza
# acdc/fireyourguns
# kaykyserhisorchestra/igotspursthatjinglejanglejingle
# alanjackson/chasinthatneonrainbow
# robertaflack/whereisthelove
# heroesdelsilencio/entredostierras
# deeelite/grooveisintheheart
# johnnygill/rubyoutherightway
# aliceinchains/wedieyoung
# ricardomontaner/lacimadelcielo
# thehighwaymen/americanremains
# joediffie/biggerthanthebeatles
# aliceinchains/bleedthefreak
# paulsimon/theobviouschild
# dougstone/idbebetteroffinapinebox
# icecube/theniggayalovetohate
# donnyhathaway/asongforyou
# atribecalledquest/ileftmywalletinelsegundo
# josjos/loquenofuenoser
# atribecalledquest/luckoflucien
# bellbivdevoe/whenwilliseeyousmileagain
# blackbox/everybodyeverybody
# tommydorsey/illneversmileagain
# janesaddiction/beencaughtstealing
# yt/summertimegirlsstudioversion
# atribecalledquest/bonitaapplebumincludescanikickitintro
# ride/vapourtrail
# vanmorrison/realrealgone
# jandean/surfcityremastered1990stereoremix
# heroesdelsilencio/entredostierras
# travistritt/imgonnabesomebody
# tonytoniton/whateveryouwant
# theblackcrowes/jealousagain
# bellbivdevoe/dome
# mauriceravel/mamreloyem60versionforpianoduoipavanedelabelleauboisdormant
# tonyterry/withyou
# depechemode/worldinmyeyes2006remasteredversion
# depechemode/enjoythesilence2006remasteredversion
# felixmendelssohn/liederohnewortesongswithoutwordsbook2op30no7ineflatmajorop30no1
# mariahcarey/lovetakestime
# uncletupelo/moonshiner
# mazzystar/halah
# aliceinchains/seaofsorrow
# chayanne/tiempodevals
# slayer/deadskinmask
# anthrax/gotthetime
# inxs/suicideblonde
# therascals/abeautifulmorning
# templeofthedog/callmeadog
# joediffie/propmeupbesidethejukeboxifidie
# phish/bouncingaroundtheroom
# concreteblonde/joey
# alejandraguzman/llamaporfavor
# travistritt/countryclub
# conwaytwitty/saturdaynightspecial
# orleans/stilltheone
# lynchmob/wickedsensation
# candyman/knockinboots
# josjos/almohada
# sergeirachmaninoff/vocaliseop34no14versionforcelloandpiano
# lightershadeofbrown/latinactive
# pantera/primalconcretesledge
# man/perdidoenunbarco
# slayer/warensemble
# pandora/cmotevamiamor
# slayer/seasonsintheabyss
# davidbowie/modernlovesingleversion1990remasteredversion
# enigma/principlesoflustsadenessfindlovesadenessreprise
# marychapincarpenter/ifeellucky
# vicentefernndez/deunranchoaotro
# dramarama/anythinganything[illgiveyou][liveatthechinaclub]
# johannsebastianbach/orchestralsuiteno3indmajorbwv10682air
# traciespencer/tenderkisses
# whitneyhouston/allthemanthatineed
# keithwhitley/miamimyamy
# thecry/alone
# aliceinchains/itaintlikethat
# aliceinchains/lovehatelove
# pixies/velouria
# thecharlatans/theonlyoneiknow
# pantera/psychoholiday
# monielove/itsashamemysister
# mauriceravel/mamreloyem60versionforpianoduoiiilaideronnetteimperatricedespagodes
# theymightbegiants/particleman
# losbondadosos/unangelnodebellorar
# megadeth/takenoprisonersremastered2004
# winger/milesaway
# guayacnorquesta/oigamirevea
# damnyankees/comingofage
# derekthedominos/keepongrowingremixedversion
# camplo/luchiniakathisisit
# badcompany/ifyouneededsomebody
# wilsonphillips/releaseme
# thebangles/manicmonday
# snap/thepower
# sinadoconnor/lastdayofouracquaintance
# clinedion/wheredoesmyheartbeatnow
# cocteautwins/pitchthebaby
# primus/thetoysgowindingdown
# joediffie/honkytonkattitude
# hifive/icantwaitanotherminute
# keithwhitley/imoveryou
# beegees/stayinalivefromsaturdaynightfeversoundtrack
# mariahcarey/someday
# claudedebussy/deuxarabesquesl66no1andanteconmoto
# blackbox/strikeitup
# poison/ridethewind
# robertaflack/thecloserigettoyou
# danieljohnston/truelovewillfindyouintheend
# templeofthedog/timesoftrouble
# therighteousbrothers/youremysoulandinspiration
# ricardomontaner/djamellorar
# andrewlloydwebber/thephantomoftheopera
# caifanes/losdiosesocultos
# suicidaltendencies/youcantbringmedown
# pantera/heresy
# thejeffhealeyband/whilemyguitargentlyweeps
# thegogos/headoverheels
# mariahcarey/idontwannacry
# juangabriel/amoreternoenvivoenelpalaciodebellasartes
# branfordmarsalisquartet/mobetterblues
# sodastereo/demsicaligeraremasterizado2007
# garymoore/stillgottheblues
# cocteautwins/iceblinkluck
# depechemode/halo2006remasteredversion
# ratt/givinyourselfaway
# damnyankees/comeagain
# billystewart/idoloveyou
# megadeth/rustinpeacepolarisremastered2004
# johnbarry/thejohndunbarthemefilmversion
# tonytoniton/itneverrainsinsoutherncalifornia
# donnyhathaway/thischristmas
# queensrche/empireremastered2003
# fleetwoodmac/skiesthelimit
# gruponiche/unaaventura
# theromantics/talkinginyoursleep
# depechemode/personaljesus2006remasteredversion
# stevevai/fortheloveofgod
# janesaddiction/stop
# warrant/uncletomscabin
# eltonjohn/sadsongssaysomuch
# james/sitdown
# enigma/meaculpa
# megadeth/fivemagicsremastered2004
# bennygoodman/stompinatthesavoy
# firehouse/allshewrotelive
# thebangles/hazyshadeofwinter
# losprisioneros/trenalsur
# markchesnutt/brotherjukebox
# charlestrenet/lamer
# marciagriffiths/electricboogie
# madonna/crazyforyoueditversion
# bettemidler/fromadistance
# harryconnickjr/weareinlove
# motherlovebone/crownofthorns
# davidbowie/heroessingleversion1990remasteredversion
# iggypop/candy
# pantera/thesleep
# dannyelfman/icedance
# warrant/isawred
# wilsonphillips/youreinlove
# thejudds/lovecanbuildabridge
# extreme/getthefunkout
# tka/louderthanlove
# icecube/amerikkkasmostwanted
# digitalunderground/freaksoftheindustry
# theblackcrowes/seeingthings
# extreme/holehearted
# sergeiprokofiev/lieutenantkijop60iiromance
# fleetwoodmac/loveisdangerous
# tesla/signsliveatthetrocadero1990
# danzig/devilsplaything
# slayer/skeletonsofsociety
# gruponiche/buscapordentro
# danieljohnston/somethingslastalongtime
# petshopboys/beingboring2001remasteredversion
# atribecalledquest/canikickitjcoleremix
# eltonjohn/honkycat
# cocteautwins/fiftyfiftyclown
# templeofthedog/allnightthing
# publicenemy/welcometotheterrordome
# winger/easycomeeasygo
# texastornados/heybabyquepaso
# conwaytwitty/goodbyetime
# jawbreaker/want
# hankwilliamsjr/mrlincoln
# selena/yaves
# thepogues/whiskeyinthejar
# fugazi/blueprint
# mazzystar/blueflower
# thehighwaymen/silverstallion
# markchesnutt/toocoldathome
# jethrotull/teacher
# aliceinchains/sunshine
# ricardomontaner/elpoderdetuamor
# dougstone/ineverknewlove
# ralphtresvant/dowhatigottado
# rudeboyswithgeraldlevert/writtenalloveryourface
# gruponiche/lamagiadetusbesos
# harryconnickjr/recipeforlove
# livingcolour/loverearsitsuglyhead
# megadeth/lucretiaremastered2004
# acdc/therazorsedge
# motherlovebone/thisisshangrila
# depechemode/waitingforthenight2006remasteredversion
# aliceinchains/icantremember
# geoffreyoryema/makambo
# paulsimon/cantrunbut
# dwightyoakam/turnitonturnitupturnmeloose
# beegees/howdeepisyourlove
# extreme/morethanwordsremix
# pixies/issheweird
# nelson/cantlivewithoutyourloveandaffectionremastered2017
# michaelwsmith/placeinthisworld
# josjos/amnesia
# gwar/sickofyou
# alias/morethanwordscansay
# blackbox/rideontime
# waylonjennings/wherecorndontgrow
# timmyt/onemoretry
# inxs/disappear
# depechemode/sweetestperfection2006remasteredversion
# morrissey/thelastofthefamousinternationalplayboys2010remasteredversion
# poison/lifegoesonremastered
# bellbivdevoe/bbdithoughtitwasme
# danzig/longwaybackfromhell
# travistritt/helpmeholdon
# barringtonlevy/tooexperienced
# madonna/intothegrooveeditversion
# primus/frizzlefry
# pantera/theartofshredding
# styx/showmetheway
# icecube/jackinforbeats
# ricardomontaner/castilloazul
# enigma/callaswentaway
# testament/soulsofblack
# templeofthedog/fourwalledworld
# judaspriest/nightcrawler
# comptonsmostwanted/latenighthype
# cocteautwins/froufroufoxesinmidsummerfires
# liberacin/elmueco
# donnyhathaway/somedaywellallbefree
# angelobadalamenti/twinpeaksthemeinstrumental
# n2deep/backtothehotel
# joanjetttheblackhearts/dirtydeeds
# jerryrivera/casiunhechizo
# paulsimon/thecoast
# bigdaddykane/causeicandoitright
# newkidsontheblock/tonight
# danzig/bloodandtears
# templeofthedog/pushinforwardback
# madonna/vogueedit
# happymondays/stepon2007remaster
# nelson/aftertherainremastered2017
# beyond/
# jerryrivera/caradenio
# johnprine/angelfrommontgomerylive
# gruponiche/nuestrosueo
# radiofutura/venenoenlapiel
# pixies/digforfire
# megadeth/poisonwasthecureremastered2004
# cwmccall/fourwheeldrive
# wolfgangamadeusmozart/clarinetconcertoinamajork622iiadagio
# morrissey/hairdresseronfire2010remasteredversion
# whitneyhouston/miracle
# eriksatie/3gymnopdiesgymnopedieno1
# travelingwilburys/poorhouse
# johannstraussii/thebluedanube
# traditional/earlyonemorning
# queensrche/anotherrainynightwithoutyouremastered2003
# grupotoppazdereynaldoflores/celoso
# theb52s/roamedit
# mazzystar/bemyangel
# fugazi/repeater
# francodevita/unbuenperdedor
# atribecalledquest/footprints
# theallmanbrothersband/seventurns
# man/buscndola
# primus/mrknowitall
# emilepandolfi/lesmiserablesmedley
# billyidol/cradleoflove
# jormakaukonen/genesis
# hskerd/eightmileshigh
# drivinncryin/flymecourageous
# dinahwashington/idonthurtanymore
# templeofthedog/woodenjesus
# inspiracin/elmelevantara
# guy/yearningforyourlove
# frdricchopin/nocturneno9inbmajorop32no1
# cybotron/clear
# prince/thievesinthetemple
# megadeth/dawnpatrolremastered2004
# badcompany/holywater
# thecleftones/heartandsoul
# ratt/lovingyouisadirtyjob
# keithsweat/illgiveallmylovetoyou
# johnwilliams/maintitlesomewhereinmymemoryfromhomealonevoice
# socialdistortion/sickboys
# selena/enamoradadeti
# aliceinchains/putyoudown
# llcoolj/aroundthewaygirl
# piratesofthemississippi/feedjake
# travelingwilburys/shesmybaby
# cocteautwins/iwearyourring
# garyhobbs/lasmiradas
# pebbles/lovemakesthingshappen
# morrissey/piccadillypalare2010remasteredversion
# billyjoel/tomakeyoufeelmylove
# pantera/shattered
# winger/cantgetenough
# thelas/thereshegoes
# pixies/velouria
# eltonjohn/saturdaynightsalrightforfighting
# judaspriest/atouchofevil
# slayer/deadskinmask
# gabrielfaur/sicilienneop78
# theymightbegiants/yourracistfriend
# martnvalverde/nadieteamacomoyo
# queensrche/anybodylisteningremastered2003
# trixter/giveittomegood
# gruporomance/porqueteamo
# slayer/spiritinblack
# johnprine/thatsthewaythattheworldgoesroundlive
# alanjackson/idloveyoualloveragain
# caifanes/antesdequenosolviden
# judaspriest/hellpatrol
# bluestraveler/alone
# theymightbegiants/dead
# digitalunderground/doowutchyalike
# ccmusicfactory/thingsthatmakeyougohmmmmfeatfreedomwilliams
# ironmaiden/bringyourdaughtertotheslaughter2015remaster
# whitneyhouston/mynameisnotsusan
# thewaitresses/christmaswrapping
# sonicyouth/dirtyboots
# madonna/likeavirgineditversion
# redgarlandtrio/tisautumn
# socialdistortion/sofaraway
# nwa/100milesandrunnin
# theblackcrowes/sisterluck
# joediffie/thirdrockfromthesun
# aliceinchains/confusion
# danzig/herblackwings
# jamesbrown/livinginamerica
# thecleftones/littlegirlofmine
# mazzystar/giveyoumylovin
# sammydavisjr/iaintgotnobody
# leonardofavio/dingdongdingdongesascosasdelamor
# joediffie/sohelpmegirl
# aliceinchains/realthing
# brandnubian/allforone
# gloriaestefan/conga
# cocteautwins/fotzepolitic
# mylifewiththethrillkillkult/adaisychain4satanacidflowerzmix
# judaspriest/allgunsblazing
# depechemode/bluedress2006remasteredversion
# thecleftones/cantwebesweethearts
# bellbivdevoe/idoneedyou
# maxipriest/closetoyou
# anagabriel/niunrocenemumtoque
# enigma/thevoiceofenigma
# atribecalledquest/pushitalong
# marychapincarpenter/downatthetwistandshout
# pixies/ana
# theventures/walkdontrun
# jerryrivera/cuentaconmigo
# mattmonro/fromrussiawithlovemonosingleversion
# juangabriel/demenamrateenvivoenelpalaciodebellasartes
# luismiguel/alguiencomot

# %%
df['lyrics'] = df.apply(lambda x: add_lyrics(x), axis=1)
df['is_english'] = df.apply(lambda x: isTextInEnglish(x['lyrics']), axis=1)

# %%
# spacy entity recognition
def entityRecognition(text):
    ret = {}
    doc = nlp(text)
    for ent in doc.ents:
        ret[(ent.label, ent.text)] = ent.label_
    return ret

# %%
df['t_entities'] = df.apply(lambda x: entityRecognition(x['lyrics']), axis=1)

# %%
df.head()
# Out:
#                        id                        name  popularity  \
# 0  57bgtoPSgt236HzfBOd8kj               Thunderstruck          82
# 1  5pKJtX4wBeby9qIfFhyOJj  Don't Go Breaking My Heart          71
# 2  6gZVQvQZOFpzIy3HblJ20F              Man in the Box          72
# 3  6m59VvDUi0UQsB2eZ9wVbH                      Poison          68
# 4  63vL5oxWrlvaJ0ayNaQnbX                    Istanbul          73
#
#    duration_ms  explicit                artist               artist_id  \
# 0       292880     False                 AC/DC  711MCceyCBcFnzjGY4Q7Un
# 1       271133     False            Elton John  3PhoLpVuITZKcymswpck5b
# 2       284426      True       Alice In Chains  64tNsm6TnZe2zpcMVMOoHL
# 3       261853     False        Bell Biv DeVoe  2zFZiWQJFFshzojycnXoTL
# 4       153813     False  They Might Be Giants  6zB02lwP6L6ZH32nggQiJT
#
#                 album                album_id album_release_date     ...      \
# 0     The Razors Edge  4vu7F6h90Br1ZtYYaqfITy         1990-09-24     ...
# 1  To Be Continued...  7iKDBfOFUtg8E8RbuDhiux         1990-11-08     ...
# 2            Facelift  5LbHbwejgZXRZAgzVAjkhj               1990     ...
# 3              Poison  6H5mxGUWguDjtQ4Uzd8veD         1990-01-01     ...
# 4               Flood  7FwAtuhhWivxvK4aPgyyUD         1990-01-02     ...
#
#   liveness  valence    tempo                      p_name  \
# 0   0.2170    0.257  133.519               thunderstruck
# 1   0.0685    0.779  131.312  don t go breaking my heart
# 2   0.2130    0.644  106.463              man in the box
# 3   0.6120    0.803  111.848                      poison
# 4   0.1360    0.892  114.144                    istanbul
#
#                p_artist                                   file_name  \
# 0                 ac dc               ./data/acdc-thunderstruck.txt
# 1            elton john  ./data/eltonjohn-dontgobreakingmyheart.txt
# 2       alice in chains        ./data/aliceinchains-maninthebox.txt
# 3        bell biv devoe              ./data/bellbivdevoe-poison.txt
# 4  they might be giants       ./data/theymightbegiants-istanbul.txt
#
#    has_lyrics  lyrics  is_english  t_entities
# 0           0               False          {}
# 1           0               False          {}
# 2           0               False          {}
# 3           0               False          {}
# 4           0               False          {}
#
# [5 rows x 30 columns]

# %%
def scoresFromFile(termScoreFile):
    scores = {}
    with open(termScoreFile, 'r') as f:
        for line in f:
            term, score = line.split("\t")
            scores[term] = float(score)
    return scores

scores165 = scoresFromFile('{}/{}.txt'.format(AFINN_PATH, "AFINN-en-165"))
scores111 = scoresFromFile('{}/{}.txt'.format(AFINN_PATH, "AFINN-111"))

# get tokens from text, clean stopwords
def getTokens(text):
    doc = nlp(text)
    words_set = set([token.text.lower() for token in doc])
    stopwords_set = set(spacy.lang.en.stop_words.STOP_WORDS)
    contentWords = [w for w in words_set if w.lower() not in stopwords_set]
    
    return words_set

# afinn implemented analysis
def getSentiments(text, setScores = scores165):
    tokens = getTokens(text)
    score = 0
    for eachWord in tokens:
        if eachWord in setScores:
            score += setScores[eachWord]
    return score

# affin library implementarion
def afScores(text):
    return af.score(text)

def classifyScoredAfinn(scores = []):
    return [[score, 'positive'] if score > 0 
            else [score, 'negative'] if score < 0 
            else [score, 'neutral'] 
            for score in scores]
