# %%
# system import
import sys
import os
import csv
import config

# data processing
import pandas as pd
import numpy as np
#https://spacy.io/
import spacy
from spacy.tokens import Doc, Token
#https://github.com/nickdavidhaynes/spacy-cld
from spacy_cld import LanguageDetector
#https://textblob.readthedocs.io/en/dev/
from textblob import TextBlob
#https://github.com/cjhutto/vaderSentiment#installation
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#https://github.com/fnielsen/afinn
from afinn import Afinn

# set env
af = Afinn()
PROJECT_PATH = config.data_directory
AFINN_PATH = config.afinn_path

# spacy set language
nlp = spacy.load('en')
language_detector = LanguageDetector()
nlp.add_pipe(language_detector)

# %%
# file operations
def read_file(file):
    text_file = open('{}'.format(file), "r")
    text = text_file.read()
    text_file.close()
    return text

# save dataframe to csv file
def dataframe_to_csv(pDf, name = 'engSongs'):
    file_path = '{}/{}.csv'.format(PROJECT_PATH, name)
    pDf.to_csv(file_path, sep=',', encoding='utf-8', index=False)
    
# load dataFrame
df = pd.read_csv('{}/{}.csv'.format(PROJECT_PATH, 'songs'))
df.head()
# Out:
#                        id             name  popularity  duration_ms  explicit  \
# 0  57bgtoPSgt236HzfBOd8kj    Thunderstruck          82       292880     False
# 1  5u5F7qLDvZjBSktaDp4HxB       Moneytalks          64       225946     False
# 2  7A1odihHBrI8n9k0Fefh2j    Are You Ready          65       250333     False
# 3  0cLvKgKkqlaJ9UajbitH4l   Fire Your Guns          60       173746     False
# 4  4ObCns6nM6tShx5a5tHiGC  The Razors Edge          50       262533     False
#
#   artist               artist_id            album                album_id  \
# 0  AC/DC  711MCceyCBcFnzjGY4Q7Un  The Razors Edge  4vu7F6h90Br1ZtYYaqfITy
# 1  AC/DC  711MCceyCBcFnzjGY4Q7Un  The Razors Edge  4vu7F6h90Br1ZtYYaqfITy
# 2  AC/DC  711MCceyCBcFnzjGY4Q7Un  The Razors Edge  4vu7F6h90Br1ZtYYaqfITy
# 3  AC/DC  711MCceyCBcFnzjGY4Q7Un  The Razors Edge  4vu7F6h90Br1ZtYYaqfITy
# 4  AC/DC  711MCceyCBcFnzjGY4Q7Un  The Razors Edge  4vu7F6h90Br1ZtYYaqfITy
#
#   album_release_date                        ...                          key  \
# 0         1990-09-24                        ...                            4
# 1         1990-09-24                        ...                            7
# 2         1990-09-24                        ...                            7
# 3         1990-09-24                        ...                            9
# 4         1990-09-24                        ...                            4
#
#   loudness mode speechiness  acousticness  instrumentalness  liveness  \
# 0   -5.175    1      0.0364      0.000147          0.011400    0.2170
# 1   -3.677    1      0.0314      0.000841          0.000351    0.1220
# 2   -4.816    1      0.0324      0.016500          0.000004    0.1300
# 3   -3.284    1      0.0508      0.001350          0.000007    0.0941
# 4   -3.522    1      0.0532      0.001080          0.196000    0.1680
#
#    valence    tempo                                             genres
# 0    0.257  133.519  ['album rock', 'australian rock', 'hard rock',...
# 1    0.409  121.896  ['album rock', 'australian rock', 'hard rock',...
# 2    0.414  108.533  ['album rock', 'australian rock', 'hard rock',...
# 3    0.515   98.879  ['album rock', 'australian rock', 'hard rock',...
# 4    0.306  101.058  ['album rock', 'australian rock', 'hard rock',...
#
# [5 rows x 27 columns]

# %%
def isTextInEnglish(text):
    doc = nlp(text)
    languages = doc._.languages
    try:
        score = doc._.language_scores['en']
        return score > 0.75
    except:
        return False

# %%
# text cleansing 
def clean_text(text):
    return text.replace('"',"'").replace('“','"').replace('”','"').replace('’','"').replace('‘','"')

def add_lyrics(row):
    if row['has_lyrics'] == True:
        return clean_text(read_file(row['file_name']))
    else:
        return ''
    
def get_lyric_name_path(a, t):
    aaz = a.replace(' ', '').lower()
    taz = t.replace(' ', '').lower()
    title = '{}/{}'.format(aaz, taz)
    print(title)
    file_path = '{}/{}.txt'.format(PROJECT_PATH, title.replace('/','-'))
    path = [title, file_path]

    if not os.path.exists(file_path):
        return path + [True]
    else:
        return path + [False]

# %%
df['lyrics'] = df.apply(lambda x: add_lyrics(x), axis=1)

# %%
df['is_english'] = df.apply(lambda x: isTextInEnglish(x['lyrics']), axis=1)

# %%
df_eng = df[df['is_english'] == True].copy()

# %%
# spacy entity recognition
def entityRecognition(text):
    ret = {}
    doc = nlp(text)
    for ent in doc.ents:
        ret[(ent.label, ent.text)] = ent.label_
    return ret

# %%
df_eng['t_entities'] = df_eng.apply(lambda x: entityRecognition(x['lyrics']), axis=1)

# %%
Doc.set_extension('vader_neutral', default=None, force=True)
Doc.set_extension('vader_positive', default=None, force=True)
Doc.set_extension('vader_negative', default=None, force=True)
#Token.set_extension('vader_neutral', default=None, force=True)
#Token.set_extension('vader_positive', default=None, force=True)

# %%
sid_obj = SentimentIntensityAnalyzer()

def vader_pipe(doc):
    sentiment_dict = sid_obj.polarity_scores(doc.text)
    
    doc._.vader_negative = sentiment_dict['neg']
    doc._.vader_neutral = sentiment_dict['neu']
    doc._.vader_positive = sentiment_dict['pos']
    
    #for sentence in doc.sents:
    #    for token in sentence:
    #        sentiment_dict_token = sid_obj.polarity_scores(token.text)
    #        token._.vader_negative = sentiment_dict_token['neg']
    #        token._.vader_neutral = sentiment_dict_token['neu']
    #        token._.vader_positive = sentiment_dict_token['pos']

    return doc

# %%
if nlp.has_pipe('vader_pipe'):
    nlp.remove_pipe('vader_pipe')
nlp.add_pipe(vader_pipe)

# %%
Doc.set_extension('tb_subjectivity', default=None, force=True)
Doc.set_extension('tb_polarity', default=None, force=True)

# %%
def textblob_pipe(doc):
    textBlobText = TextBlob(doc.text)
    
    doc._.tb_polarity = textBlobText.sentiment[0]
    doc._.tb_subjectivity = textBlobText.sentiment[1]

    return doc

# %%
if nlp.has_pipe('textblob_pipe'):
    nlp.remove_pipe('textblob_pipe')
nlp.add_pipe(textblob_pipe)

# %%
Doc.set_extension('sAfinn_score', default=None, force=True)
Doc.set_extension('afinn_score', default=None, force=True)

# %%
def scoresFromFile(termScoreFile):
    scores = {}
    with open(termScoreFile, 'r') as f:
        for line in f:
            term, score = line.split("\t")
            scores[term] = float(score)
    return scores

scores165 = scoresFromFile('{}/{}.txt'.format(AFINN_PATH, "AFINN-en-165"))
scores111 = scoresFromFile('{}/{}.txt'.format(AFINN_PATH, "AFINN-111"))

# get tokens from text, clean stopwords
def getTokens(text):
    doc = text.split()
    words_set = set([token.lower() for token in doc])
    stopwords_set = set(spacy.lang.en.stop_words.STOP_WORDS)
    contentWords = [w for w in words_set if w.lower() not in stopwords_set]
    
    return words_set

# afinn implemented analysis
def getSentiments(text, setScores = scores165):
    tokens = getTokens(text)
    score = 0
    for eachWord in tokens:
        if eachWord in setScores:
            score += setScores[eachWord]
    return score

# affin library implementarion
def afScores(text):
    return af.score(text)

def classifyScoredAfinn(scores = []):
    return [[score, 'positive'] if score > 0 
            else [score, 'negative'] if score < 0 
            else [score, 'neutral'] 
            for score in scores]

def afinn_pipe(doc):
    doc._.sAfinn_score = afScores(doc.text)
    doc._.afinn_score = getSentiments(doc.text)

    return doc

# %%
if nlp.has_pipe('afinn_pipe'):
    nlp.remove_pipe('afinn_pipe')
nlp.add_pipe(afinn_pipe)

# %%
df_eng['subjectivity'] = ''
df_eng['polarity'] = ''
df_eng['positivity'] = ''
df_eng['neutrality'] = ''
df_eng['negativity'] = ''
df_eng['safinn_score'] = ''
df_eng['afinn_score'] = ''

# %%
for index, row in df_eng.iterrows():
    nlpElem = nlp(row.lyrics)
    df_eng.loc[index, 'subjectivity'] = nlpElem._.tb_subjectivity
    df_eng.loc[index, 'polarity'] = nlpElem._.tb_polarity
    df_eng.loc[index, 'positivity'] = nlpElem._.vader_positive
    df_eng.loc[index, 'neutrality'] = nlpElem._.vader_neutral
    df_eng.loc[index, 'negativity'] = nlpElem._.vader_negative
    df_eng.loc[index, 'safinn_score'] = nlpElem._.sAfinn_score
    df_eng.loc[index, 'afinn_score'] = nlpElem._.afinn_score

# %%
df_eng["explicit"] = df_eng["explicit"].astype(int)

# %%
df_eng.set_index('id')
# Out:
#                                                            name  popularity  \
# id
# 57bgtoPSgt236HzfBOd8kj                            Thunderstruck          82
# 5u5F7qLDvZjBSktaDp4HxB                               Moneytalks          64
# 7A1odihHBrI8n9k0Fefh2j                            Are You Ready          65
# 0cLvKgKkqlaJ9UajbitH4l                           Fire Your Guns          60
# 4ObCns6nM6tShx5a5tHiGC                          The Razors Edge          50
# 5pKJtX4wBeby9qIfFhyOJj               Don't Go Breaking My Heart          71
# 1fF2dvBsbTk2wrOEaR6f5B                  Sad Songs (Say So Much)          50
# 4wlB8D6OZpHEz3kXVuYD2O                                Honky Cat          48
# 4i6wwcBc3Qrqir83xBdbM6  Saturday Night's Alright (For Fighting)          41
# 6gZVQvQZOFpzIy3HblJ20F                           Man in the Box          72
# 5Ds35L9KpUDKgSxZ6whuoQ                             We Die Young          54
# 60l2m3BD5VY0HSc3xmSpPI                          Bleed The Freak          53
# 4XssnBT81vTIH6iYYUSv84                            Sea Of Sorrow          51
# 3P5IxgmbTBhBV6qE867LmD                       It Ain't Like That          50
# 2YolSRrYvFxhTGjbiT33yH                         Love, Hate, Love          50
# 0X87YlD94elwfFPvYAP1Gy                   5     ...
# 33I3oS8UkebR3KRvqxD9X0                  12     ...
# 20tRwxVyguyMwijkNtH8oP                  16     ...
#
#                                                                    lyrics  \
# id
# 57bgtoPSgt236HzfBOd8kj    Thunder [x10] I was caught In the middle of ...
# 5u5F7qLDvZjBSktaDp4HxB    Tailored suits, chauffeured cars Fine hotels...
# 7A1odihHBrI8n9k0Fefh2j    Sweet apple pie Standing in the street Hands...
# 0cLvKgKkqlaJ9UajbitH4l    Wild beast I'll make you mine Taste your kis...
# 4ObCns6nM6tShx5a5tHiGC    There's fightin' on the left And marching on...
# 5pKJtX4wBeby9qIfFhyOJj    Don't go breaking my heart I couldn't if I t...
# 1fF2dvBsbTk2wrOEaR6f5B    Guess there are times when we all need to sh...
# 4wlB8D6OZpHEz3kXVuYD2O    When I look back boy I must have been green ...
# 4i6wwcBc3Qrqir83xBdbM6    It's getting late have you seen my mates Ma ...
# 6gZVQvQZOFpzIy3HblJ20F    I'm the man in the box [Album version:] Buri...
# 5Ds35L9KpUDKgSxZ6whuoQ    Scary's on the wall Scary's on his way  Watc...
# 60l2m3BD5VY0HSc3xmSpPI    My cup runneth over Like blood from a stone ...
# 4XssnBT81vTIH6iYYUSv84    Mind, of destructive taste I choose...to str...
# 3P5IxgmbTBhBV6qE867LmD    There I was, laid out on a table Screamin' s...
# 2YolSRrYvFxhTGjbiT33yH    I tried to love you I thought I could I trie...
# 6gnvB7ejTWObv3d2xdCaL4    One, a-one time, yeah  Am I too contagious F...
# 4aSCbMw2Nw2eQkJ0okcp8q    Turn around you say 'Scuse the 'tude but I h...
# 4ndE8nr81B9b0q4RfIqEGw    Heartbreaker, feelin' alright Body over...mi...
# 5fuilHPCSViseXRrKMEFns    There's no time to give at all I cause you g...
# 41HCZr5cOMuiX2z5Gbi1qi    I messed around as a little boy I grew up, m...
# 6m59VvDUi0UQsB2eZ9wVbH    [Michael Bivins:] Yeah, Spiderman and Freeze...
# 3q0QmvdwHBETS89ZvelClL    La da da da da da da La da da da da da da da...
# 3an1aoJKoBXJKoIfdDbVwf    Take a good look at me Tell me do you like w...
# 4oRDt0qQeY4XQOQWYOQUmt    [B.B.D.: ad-libs in background for 30 second...
# 23zldSU989tN8OLQ4tPrZj    Hey baby, I've been clockin' it for a while ...
# 63vL5oxWrlvaJ0ayNaQnbX    Istanbul was Constantinople Now it's Istanbu...
# 6pmuu4qSz2WrtGkBjUfyuz    I'm your only friend I'm not your only frien...
# 1WFCIkoc4PaN7L7SmiI85i    Particle man, particle man Doing the things ...
# 6hNrg9cIjyWuklYGWIduy5    This is where the party ends I can't stand h...
# 0nKGeWn6Y4VEbRdSRJ3Y6P    I returned a bag of groceries Accidently tak...
# ...                                                                   ...
# 48eiLW57CqSmCYNZRM2J8M    From a distance the world looks blue and gre...
# 0cPa96zXRs2LVuNIqu06oj    I know you so well I can tell by the sound o...
# 1xe4IvNW94G8R4KCHrLUt6    A little bit of me and a whole lot of you Ad...
# 2AFN49ptbSNP7JJr6XkLXV    Love is a flame A devil's thing A violent st...
# 4wM61bPrvM8HScuxtskTbd    Blackest of the black Darker than night Come...
# 6sD2mCUjmi0S3PTKxdW1Lc    Yea Sold into slavery down in New Orleans Go...
# 1Gt07aYIpl5yJcTbH95s7v    Blood and tears Blood and tears Since you've...
# 0EWhS9tnh5XC7LP4mfEg1C    Mr. Lincoln I wish you were here The Republi...
# 1e75rLMvgoIGX5wnwUA7q0    Well the dawn was coming, heard him ringing ...
# 39kXSNeX4g5wENfe3Vr2dX    I'm not playing with you, I'm not playing wi...
# 3aJ1usdhO4jQ5VAFiet0CL    You say I need a job, I've got my own busine...
# 5huSgTVqBdIJTFhpShJfcg    Yeah ehh ehh Ah oooh ooh Dib um dib dib dib ...
# 0JyuEt2VTlBvGMBrM1XJ5x    Well I'm back again for another night Of try...
# 0Um0yXpdTbbi0qUMWB3kIs    Your socks they smell, your feet they stink,...
# 0PKTBeN87JYJ1mRzrq5Aog    The wind is moving But I am standing still A...
# 1EB3Z38oKDKVp4K2yEO2dl    Here I am at six o'clock in the morning Stil...
# 0lChO8MEC0eWVBznAMIWE6    As we sat on the front porch of that old gre...
# 2upjcGvuiTCGSaGPZZ2dtD    Every night I say a prayer in the hope that ...
# 1Se858cFyzqNuGhGcOF9qy    She doesn't want me... around  She's got  so...
# 5zAN2OQJsmcBVG1oO5QroD    Can't you see That in the world we live in P...
# 0mSpQL0vAloSJS6CTWoGJw    You walk in, half past nine Lookin' like a q...
# 74i07fyJWNPDR5q56Wi8vU    She's got her pudding in the oven And it's g...
# 5TSANSqPTD6nBG0NSJWmVB    Well rock the cradle of love Rock the cradle...
# 403oiKw757eJnbDKPSjhHV    Love come quick Love come in a hurry There a...
# 6KaNr5y4GAlHGp2dQiZNPs    When the rain is blowing in your face And th...
# 6SdPDNYIs34H0MWBrrfH6T    Baby, baby, baby My, my, my, my baby I love ...
# 5J8FSmpybnVziZhErdhZlT    Deep in the heart Love has many ways Of touc...
# 0X87YlD94elwfFPvYAP1Gy    [Intro:]  And why do we call ourself 'Niggaz...
# 33I3oS8UkebR3KRvqxD9X0    She was a jezebel, this Brixtonqueen Livin' ...
# 20tRwxVyguyMwijkNtH8oP    Looking down on empty streets, all she can s...
#
#                        is_english  \
# id
# 57bgtoPSgt236HzfBOd8kj       True
# 5u5F7qLDvZjBSktaDp4HxB       True
# 7A1odihHBrI8n9k0Fefh2j       True
# 0cLvKgKkqlaJ9UajbitH4l       True
# 4ObCns6nM6tShx5a5tHiGC       True
# 5pKJtX4wBeby9qIfFhyOJj       True
# 1fF2dvBsbTk2wrOEaR6f5B       True
# 4wlB8D6OZpHEz3kXVuYD2O       True
# 4i6wwcBc3Qrqir83xBdbM6       True
# 6gZVQvQZOFpzIy3HblJ20F       True
# 5Ds35L9KpUDKgSxZ6whuoQ       True
# 60l2m3BD5VY0HSc3xmSpPI       True
# 4XssnBT81vTIH6iYYUSv84       True
# 3P5IxgmbTBhBV6qE867LmD       True
# 2YolSRrYvFxhTGjbiT33yH       True
# 6gnvB7ejTWObv3d2xdCaL4       True
# 4aSCbMw2Nw2eQkJ0okcp8q       True
# 4ndE8nr81B9b0q4RfIqEGw       True
# 5fuilHPCSViseXRrKMEFns       True
# 41HCZr5cOMuiX2z5Gbi1qi       True
# 6m59VvDUi0UQsB2eZ9wVbH       True
# 3q0QmvdwHBETS89ZvelClL       True
# 3an1aoJKoBXJKoIfdDbVwf       True
# 4oRDt0qQeY4XQOQWYOQUmt       True
# 23zldSU989tN8OLQ4tPrZj       True
# 63vL5oxWrlvaJ0ayNaQnbX       True
# 6pmuu4qSz2WrtGkBjUfyuz       True
# 1WFCIkoc4PaN7L7SmiI85i       True
# 6hNrg9cIjyWuklYGWIduy5       True
# 0nKGeWn6Y4VEbRdSRJ3Y6P       True
# ...                           ...
# 48eiLW57CqSmCYNZRM2J8M       True
# 0cPa96zXRs2LVuNIqu06oj       True
# 1xe4IvNW94G8R4KCHrLUt6       True
# 2AFN49ptbSNP7JJr6XkLXV       True
# 4wM61bPrvM8HScuxtskTbd       True
# 6sD2mCUjmi0S3PTKxdW1Lc       True
# 1Gt07aYIpl5yJcTbH95s7v       True
# 0EWhS9tnh5XC7LP4mfEg1C       True
# 1e75rLMvgoIGX5wnwUA7q0       True
# 39kXSNeX4g5wENfe3Vr2dX       True
# 3aJ1usdhO4jQ5VAFiet0CL       True
# 5huSgTVqBdIJTFhpShJfcg       True
# 0JyuEt2VTlBvGMBrM1XJ5x       True
# 0Um0yXpdTbbi0qUMWB3kIs       True
# 0PKTBeN87JYJ1mRzrq5Aog       True
# 1EB3Z38oKDKVp4K2yEO2dl       True
# 0lChO8MEC0eWVBznAMIWE6       True
# 2upjcGvuiTCGSaGPZZ2dtD       True
# 1Se858cFyzqNuGhGcOF9qy       True
# 5zAN2OQJsmcBVG1oO5QroD       True
# 0mSpQL0vAloSJS6CTWoGJw       True
# 74i07fyJWNPDR5q56Wi8vU       True
# 5TSANSqPTD6nBG0NSJWmVB       True
# 403oiKw757eJnbDKPSjhHV       True
# 6KaNr5y4GAlHGp2dQiZNPs       True
# 6SdPDNYIs34H0MWBrrfH6T       True
# 5J8FSmpybnVziZhErdhZlT       True
# 0X87YlD94elwfFPvYAP1Gy       True
# 33I3oS8UkebR3KRvqxD9X0       True
# 20tRwxVyguyMwijkNtH8oP       True
#
#                                                                t_entities  \
# id
# 57bgtoPSgt236HzfBOd8kj  {(384, 'Beating'): 'GPE', (380, 'Thunderstruck...
# 5u5F7qLDvZjBSktaDp4HxB  {(390, 'the Moneytalk Come'): 'LAW', (381, 'Fr...
# 7A1odihHBrI8n9k0Fefh2j                                                 {}
# 0cLvKgKkqlaJ9UajbitH4l                         {(380, 'Sweet'): 'PERSON'}
# 4ObCns6nM6tShx5a5tHiGC                         {(380, 'Razor'): 'PERSON'}
# 5pKJtX4wBeby9qIfFhyOJj                             {(383, 'Baby'): 'ORG'}
# 1fF2dvBsbTk2wrOEaR6f5B  {(383, 'Cause'): 'ORG', (381, 'Sad'): 'NORP', ...
# 4wlB8D6OZpHEz3kXVuYD2O  {(381, 'Better'): 'NORP', (384, 'New Orleans')...
# 4i6wwcBc3Qrqir83xBdbM6  {(380, 'Ma'): 'PERSON', (392, 'seven o'clock')...
# 6gZVQvQZOFpzIy3HblJ20F  {(380, 'Jesus Christ'): 'PERSON', (383, 'Music...
# 5Ds35L9KpUDKgSxZ6whuoQ  {(380, 'Down'): 'PERSON', (380, 'Bullet'): 'PE...
# 60l2m3BD5VY0HSc3xmSpPI  {(397, 'one'): 'CARDINAL', (383, 'BLEED FOR'):...
# 4XssnBT81vTIH6iYYUSv84                        {(391, 'tomorrow'): 'DATE'}
# 3P5IxgmbTBhBV6qE867LmD  {(384, 'Screamin'): 'GPE', (383, 'Feel'): 'ORG...
# 2YolSRrYvFxhTGjbiT33yH  {(381, 'Sweet'): 'NORP', (380, 'Lying'): 'PERS...
# 6gnvB7ejTWObv3d2xdCaL4  {(383, 'the Mother Mother'): 'ORG', (380, 'Suc...
# 4aSCbMw2Nw2eQkJ0okcp8q  {(380, 'Scuse'): 'PERSON', (384, 'Screamin'): ...
# 4ndE8nr81B9b0q4RfIqEGw   {(385, 'Ooo'): 'LOC', (386, 'Shoot'): 'PRODUCT'}
# 5fuilHPCSViseXRrKMEFns  {(380, 'Love'): 'PERSON', (384, 'Drilling'): '...
# 41HCZr5cOMuiX2z5Gbi1qi  {(383, 'Friends'): 'ORG', (380, 'Gimme'): 'PER...
# 6m59VvDUi0UQsB2eZ9wVbH  {(380, 'Michael Bivins'): 'PERSON', (380, 'Spi...
# 3q0QmvdwHBETS89ZvelClL  {(380, 'Ooh'): 'PERSON', (397, 'one'): 'CARDIN...
# 3an1aoJKoBXJKoIfdDbVwf  {(380, 'Kiss'): 'PERSON', (380, 'Girl'): 'PERS...
# 4oRDt0qQeY4XQOQWYOQUmt  {(392, '30 seconds'): 'TIME', (380, 'Ricky Bel...
# 23zldSU989tN8OLQ4tPrZj  {(380, 'Keep'): 'PERSON', (380, 'Hoo Hoo'): 'P...
# 63vL5oxWrlvaJ0ayNaQnbX  {(384, 'Istanbul'): 'GPE', (383, 'Constantinop...
# 6pmuu4qSz2WrtGkBjUfyuz  {(380, 'Filibuster'): 'PERSON', (380, 'Jason')...
# 1WFCIkoc4PaN7L7SmiI85i  {(383, 'Triangle'): 'ORG', (383, 'Universe'): ...
# 6hNrg9cIjyWuklYGWIduy5                                                 {}
# 0nKGeWn6Y4VEbRdSRJ3Y6P  {(383, 'Accidently'): 'ORG', (397, 'eight'): '...
# ...                                                                   ...
# 48eiLW57CqSmCYNZRM2J8M                                                 {}
# 0cPa96zXRs2LVuNIqu06oj                         {(380, 'Kneel'): 'PERSON'}
# 1xe4IvNW94G8R4KCHrLUt6  {(397, 'dozen'): 'CARDINAL', (391, 'a hundred ...
# 2AFN49ptbSNP7JJr6XkLXV  {(380, 'Gentle'): 'PERSON', (380, 'Got'): 'PER...
# 4wM61bPrvM8HScuxtskTbd  {(384, 'Darker'): 'GPE', (380, 'Enter'): 'PERS...
# 6sD2mCUjmi0S3PTKxdW1Lc  {(380, 'Yea Sold'): 'PERSON', (388, 'New Orlea...
# 1Gt07aYIpl5yJcTbH95s7v  {(383, 'Blood'): 'ORG', (380, 'Blood'): 'PERSO...
# 0EWhS9tnh5XC7LP4mfEg1C  {(380, 'Lincoln'): 'PERSON', (391, 'a hundred ...
# 1e75rLMvgoIGX5wnwUA7q0                          {(380, 'Jump'): 'PERSON'}
# 39kXSNeX4g5wENfe3Vr2dX                                                 {}
# 3aJ1usdhO4jQ5VAFiet0CL  {(384, 'Knowing'): 'GPE', (397, '1'): 'CARDINA...
# 5huSgTVqBdIJTFhpShJfcg                          {(380, 'Love'): 'PERSON'}
# 0JyuEt2VTlBvGMBrM1XJ5x  {(392, 'another night'): 'TIME', (380, 'Buck O...
# 0Um0yXpdTbbi0qUMWB3kIs                                                 {}
# 0PKTBeN87JYJ1mRzrq5Aog  {(380, 'Roamin'): 'PERSON', (392, 'the night')...
# 1EB3Z38oKDKVp4K2yEO2dl  {(392, 'six o'clock in the morning'): 'TIME', ...
# 0lChO8MEC0eWVBznAMIWE6                                                 {}
# 2upjcGvuiTCGSaGPZZ2dtD  {(391, 'every day'): 'DATE', (392, 'tonight'):...
# 1Se858cFyzqNuGhGcOF9qy                                                 {}
# 5zAN2OQJsmcBVG1oO5QroD  {(380, 'Seem'): 'PERSON', (380, 'Will'): 'PERS...
# 0mSpQL0vAloSJS6CTWoGJw  {(397, 'half past nine'): 'CARDINAL', (383, 'L...
# 74i07fyJWNPDR5q56Wi8vU  {(384, 'Hollywood'): 'GPE', (380, 'Honey'): 'P...
# 5TSANSqPTD6nBG0NSJWmVB  {(383, 'Cause'): 'ORG', (397, 'million'): 'CAR...
# 403oiKw757eJnbDKPSjhHV  {(392, 'tonight'): 'TIME', (397, '2'): 'CARDIN...
# 6KaNr5y4GAlHGp2dQiZNPs  {(392, 'evening'): 'TIME', (391, 'a million ye...
# 6SdPDNYIs34H0MWBrrfH6T  {(392, 'tonight'): 'TIME', (380, 'Girl'): 'PER...
# 5J8FSmpybnVziZhErdhZlT  {(380, 'Love'): 'PERSON', (386, 'Love'): 'PROD...
# 0X87YlD94elwfFPvYAP1Gy  {(386, 'Miles'): 'PRODUCT', (383, 'Runnin'): '...
# 33I3oS8UkebR3KRvqxD9X0  {(383, 'this Brixtonqueen Livin''): 'ORG', (38...
# 20tRwxVyguyMwijkNtH8oP  {(384, 'Nowhere'): 'GPE', (381, 'Words'): 'NOR...
#
#                         subjectivity     polarity  positivity  neutrality  \
# id
# 57bgtoPSgt236HzfBOd8kj      0.399074     0.275926       0.232       0.664
# 5u5F7qLDvZjBSktaDp4HxB      0.330324    0.0425926       0.025       0.961
# 6gnvB7ejTWObv3d2xdCaL4        0.05            23            5
# 4aSCbMw2Nw2eQkJ0okcp8q       0.218           -14          -15
# 4ndE8nr81B9b0q4RfIqEGw       0.122           -10          -10
# 5fuilHPCSViseXRrKMEFns       0.311           -21          -11
# 41HCZr5cOMuiX2z5Gbi1qi       0.029            10            3
# 6m59VvDUi0UQsB2eZ9wVbH        0.07             6            6
# 3q0QmvdwHBETS89ZvelClL       0.102           -29           -9
# 3an1aoJKoBXJKoIfdDbVwf       0.007            29           10
# 4oRDt0qQeY4XQOQWYOQUmt       0.026            55           11
# 23zldSU989tN8OLQ4tPrZj       0.028            17            9
# 63vL5oxWrlvaJ0ayNaQnbX       0.024             9            7
# 6pmuu4qSz2WrtGkBjUfyuz       0.031            22            3
# 1WFCIkoc4PaN7L7SmiI85i       0.128             2            5
# 6hNrg9cIjyWuklYGWIduy5        0.19           -30           -7
# 0nKGeWn6Y4VEbRdSRJ3Y6P       0.055             5           -5
# ...                            ...           ...          ...
# 48eiLW57CqSmCYNZRM2J8M       0.065            34            5
# 0cPa96zXRs2LVuNIqu06oj           0            26            8
# 1xe4IvNW94G8R4KCHrLUt6       0.047            14            6
# 2AFN49ptbSNP7JJr6XkLXV       0.083           -16           -9
# 4wM61bPrvM8HScuxtskTbd        0.05           -14           -9
# 6sD2mCUjmi0S3PTKxdW1Lc       0.211           -35          -21
# 1Gt07aYIpl5yJcTbH95s7v       0.346           -64          -16
# 0EWhS9tnh5XC7LP4mfEg1C       0.086             1           -8
# 1e75rLMvgoIGX5wnwUA7q0       0.086             9            0
# 39kXSNeX4g5wENfe3Vr2dX       0.131             1            3
# 3aJ1usdhO4jQ5VAFiet0CL       0.102            -4           -4
# 5huSgTVqBdIJTFhpShJfcg       0.267           -11           -2
# 0JyuEt2VTlBvGMBrM1XJ5x       0.175           -13            2
# 0Um0yXpdTbbi0qUMWB3kIs       0.271           -18            0
# 0PKTBeN87JYJ1mRzrq5Aog           0            12            8
# 1EB3Z38oKDKVp4K2yEO2dl       0.056             8            3
# 0lChO8MEC0eWVBznAMIWE6       0.085             3            5
# 2upjcGvuiTCGSaGPZZ2dtD        0.08            10            6
# 1Se858cFyzqNuGhGcOF9qy       0.072            -8           -5
# 5zAN2OQJsmcBVG1oO5QroD       0.168           -22           -9
# 0mSpQL0vAloSJS6CTWoGJw        0.21           -14            1
# 74i07fyJWNPDR5q56Wi8vU       0.024            10            7
# 5TSANSqPTD6nBG0NSJWmVB        0.08            92            4
# 403oiKw757eJnbDKPSjhHV       0.177            51           13
# 6KaNr5y4GAlHGp2dQiZNPs       0.075            17            3
# 6SdPDNYIs34H0MWBrrfH6T       0.051            31            6
# 5J8FSmpybnVziZhErdhZlT       0.027            84           13
# 0X87YlD94elwfFPvYAP1Gy       0.181          -129          -44
# 33I3oS8UkebR3KRvqxD9X0       0.064            32            1
# 20tRwxVyguyMwijkNtH8oP       0.084            25            2
#
# [255 rows x 36 columns]

# %%
dataframe_to_csv(df_eng)
