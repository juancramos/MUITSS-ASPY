# %%
import sys
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sys.path.append(".")
import config

client_credentials_manager = SpotifyClientCredentials(client_id=config.client_id, client_secret=config.client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

tracks = [['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artist', 'artist_id', 'album', 'album_id', 'album_release_date', 'album_release_date_precision', 'album_total_tracks']]

for i in range(0,1,1):
    track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        tracks.append([t['id'], t['name'], t['popularity'], t['duration_ms'], t['explicit'], t['artists'][0]['name'], t['artists'][0]['id'], t['album']['release_date'], t['album']['release_date_precision'], t['album']['total_tracks']])
        
tracks
# Out:
# [['id',
#   'name',
#   'popularity',
#   'duration_ms',
#   'explicit',
#   'artist',
#   'artist_id',
#   'album',
#   'album_id',
#   'album_release_date',
#   'album_release_date_precision',
#   'album_total_tracks'],
#  ['3KkXRkHbMCARz0aVfEt68P',
#   'Sunflower - Spider-Man: Into the Spider-Verse',
#   98,
#   158040,
#   False,
#   'Post Malone',
#   '246dkjvS1zLTtiykXe5h60',
#   '2018-12-14',
#   'day',
#   13],
#  ['6MWtB6iiXyIwun0YzU6DFP',
#   'Wow.',
#   98,
#   149520,
#   True,
#   'Post Malone',
#   '246dkjvS1zLTtiykXe5h60',
#   '2018-12-24',
#   'day',
#   1],
#  ['7eBqSVxrzQZtK2mmgRG6lC',
#   'Murder On My Mind',
#   94,
#   268434,
#   True,
#   'YNW Melly',
#   '1cNDP5yjU5vjeR8qMf4grg',
#   '2018-08-03',
#   'day',
#   15],
#  ['2IRZnDFmlqMuOrYOLnZZyc',
#   'Going Bad (feat. Drake)',
#   95,
#   180522,
#   True,
#   'Meek Mill',
#   '20sxb77xiYeusSH8cVdatc',
#   '2018-11-30',
#   'day',
#   19],
#  ['1wJRveJZLSb1rjhnUHQiv6',
#   'Swervin (feat. 6ix9ine)',
#   93,
# ...

# %%
ids = [e[0] for e in tracks]

n = 25
x = (len(ids) + n - 1) // n
rg = range(x)
cIds = [ids[i * n:(i + 1) * n] for i in rg]  

features = [['id', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]

for cId in cIds:
    audio_results = sp.audio_features(cId)
    for af in audio_results:
        if af:
            features.append([af['id'], af['danceability'], af['energy'], af['key'], af['loudness'], af['mode'], af['speechiness'], af['acousticness'], af['instrumentalness'], af['liveness'], af['valence'], af['tempo']])

print(features)
# Out:
# [['id', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'], ['3KkXRkHbMCARz0aVfEt68P', 0.76, 0.479, 2, -5.574, 1, 0.0466, 0.556, 0, 0.0703, 0.913, 89.911], ['6MWtB6iiXyIwun0YzU6DFP', 0.833, 0.539, 11, -7.399, 0, 0.178, 0.163, 2.1e-06, 0.101, 0.385, 99.947], ['7eBqSVxrzQZtK2mmgRG6lC', 0.759, 0.73, 0, -7.985, 0, 0.0516, 0.145, 3.06e-06, 0.11, 0.74, 115.007], ['2IRZnDFmlqMuOrYOLnZZyc', 0.889, 0.496, 4, -6.365, 0, 0.0905, 0.259, 0, 0.252, 0.544, 86.003], ['1wJRveJZLSb1rjhnUHQiv6', 0.581, 0.662, 9, -5.239, 1, 0.303, 0.0153, 0, 0.111, 0.434, 93.023], ['2t8yVaLvJ0RenpXUIAC52d', 0.837, 0.636, 1, -7.643, 1, 0.086, 0.0395, 0.00125, 0.342, 0.274, 145.972], ['78QR3Wp35dqAhFEc2qAGjE', 0.896, 0.671, 1, -6.977, 0, 0.289, 0.103, 0, 0.552, 0.358, 112.502], ['3oh6SCCeLuXhFpEyepla6G', 0.906, 0.382, 10, -12.89, 0, 0.269, 0.18, 0, 0.113, 0.391, 104.025], ['2xLMifQCjDGFmkHkpNLD9h', 0.834, 0.73, 8, -3.714, 1, 0.222, 0.0051
# ...
